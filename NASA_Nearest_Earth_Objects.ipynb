# %% [markdown]
# <a href="https://colab.research.google.com/github/bkullukcu/NASA-Nearest-Earth-Objects-R-Data-Visualization/blob/master/NASA_Nearest_Earth_Objects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data <- read.csv("neo.csv", header=TRUE, stringsAsFactors=FALSE)

# %%
str(data)
# Out:
# 'data.frame':	90836 obs. of  10 variables:
#  $ id                : int  2162635 2277475 2512244 3596030 3667127 54138696 54189957 54230078 2088213 3766065 ...
#  $ name              : chr  "162635 (2000 SS164)" "277475 (2005 WK4)" "512244 (2015 YE18)" "(2012 BV13)" ...
#  $ est_diameter_min  : num  1.1983 0.2658 0.722 0.0965 0.255 ...
#  $ est_diameter_max  : num  2.679 0.594 1.615 0.216 0.57 ...
#  $ relative_velocity : num  13569 73589 114259 24764 42738 ...
#  $ miss_distance     : num  54839744 61438127 49798725 25434973 46275567 ...
#  $ orbiting_body     : chr  "Earth" "Earth" "Earth" "Earth" ...
#  $ sentry_object     : chr  "False" "False" "False" "False" ...
#  $ absolute_magnitude: num  16.7 20 17.8 22.2 20.1 ...
#  $ hazardous         : chr  "False" "True" "False" "False" ...

# %%
ggplot(data = data) + 
  geom_point(mapping = aes(x = absolute_magnitude, y = miss_distance, color = hazardous))
# Out:
# plot without title

# %%
# left
ggplot(data = data) + 
  geom_point(mapping = aes(x = absolute_magnitude, y = est_diameter_min))

# right
ggplot(data = data) + 
  geom_smooth(mapping = aes(x = absolute_magnitude, y = est_diameter_min))
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title
# plot without title

# %%
ggplot(data = data, mapping = aes(x = relative_velocity, y = miss_distance)) + 
  geom_boxplot()
# Out:
# Warning message:
# “Continuous x aesthetic -- did you forget aes(group=...)?”
# plot without title
